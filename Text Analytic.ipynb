# %%
from nltk.tokenize import sent_tokenize
text="""Text mining, also referred to as text data mining, similar to text analytics, is the process of deriving high-quality information from text. It involves "the discovery by computer of new, previously unknown information, by automatically extracting information from different written resources."[1] Written resources may include websites, books, emails, reviews, and articles. High-quality information is typically obtained by devising patterns and trends by means such as statistical pattern learning. According to Hotho et al. (2005) we can distinguish between three different perspectives of text mining: information extraction, data mining, and a KDD (Knowledge Discovery in Databases) process.[2] Text mining usually involves the process of structuring the input text (usually parsing, along with the addition of some derived linguistic features and the removal of others, and subsequent insertion into a database), deriving patterns within the structured data, and finally evaluation and interpretation of the output. 'High quality' in text mining usually refers to some combination of relevance, novelty, and interest. Typical text mining tasks include text categorization, text clustering, concept/entity extraction, production of granular taxonomies, sentiment analysis, document summarization, and entity relation modeling (i.e., learning relations between named entities)."""
sentense_token=sent_tokenize(text)
print(sentense_token)
# Out:
# ['Text mining, also referred to as text data mining, similar to text analytics, is the process of deriving high-quality information from text.', 'It involves "the discovery by computer of new, previously unknown information, by automatically extracting information from different written resources.', '"[1] Written resources may include websites, books, emails, reviews, and articles.', 'High-quality information is typically obtained by devising patterns and trends by means such as statistical pattern learning.', 'According to Hotho et al.', '(2005) we can distinguish between three different perspectives of text mining: information extraction, data mining, and a KDD (Knowledge Discovery in Databases) process.', '[2] Text mining usually involves the process of structuring the input text (usually parsing, along with the addition of some derived linguistic features and the removal of others, and subsequent insertion into a database), deriving patterns within the structured data, and finally evaluation and interpretation of the output.', "'High quality' in text mining usually refers to some combination of relevance, novelty, and interest.", 'Typical text mining tasks include text categorization, text clustering, concept/entity extraction, production of granular taxonomies, sentiment analysis, document summarization, and entity relation modeling (i.e., learning relations between named entities).']

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aryan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
text="""Text mining, also referred to as text data mining, similar to text analytics, is the process of deriving high-quality information from text. It involves "the discovery by computer of new, previously unknown information, by automatically extracting information from different written resources."[1] Written resources may include websites, books, emails, reviews, and articles. High-quality information is typically obtained by devising patterns and trends by means such as statistical pattern learning. According to Hotho et al. (2005) we can distinguish between three different perspectives of text mining: information extraction, data mining, and a KDD (Knowledge Discovery in Databases) process.[2] Text mining usually involves the process of structuring the input text (usually parsing, along with the addition of some derived linguistic features and the removal of others, and subsequent insertion into a database), deriving patterns within the structured data, and finally evaluation and interpretation of the output. 'High quality' in text mining usually refers to some combination of relevance, novelty, and interest. Typical text mining tasks include text categorization, text clustering, concept/entity extraction, production of granular taxonomies, sentiment analysis, document summarization, and entity relation modeling (i.e., learning relations between named entities)."""
word_token=word_tokenize(text)
print(word_token)
# Out:
# ['Text', 'mining', ',', 'also', 'referred', 'to', 'as', 'text', 'data', 'mining', ',', 'similar', 'to', 'text', 'analytics', ',', 'is', 'the', 'process', 'of', 'deriving', 'high-quality', 'information', 'from', 'text', '.', 'It', 'involves', '``', 'the', 'discovery', 'by', 'computer', 'of', 'new', ',', 'previously', 'unknown', 'information', ',', 'by', 'automatically', 'extracting', 'information', 'from', 'different', 'written', 'resources', '.', '``', '[', '1', ']', 'Written', 'resources', 'may', 'include', 'websites', ',', 'books', ',', 'emails', ',', 'reviews', ',', 'and', 'articles', '.', 'High-quality', 'information', 'is', 'typically', 'obtained', 'by', 'devising', 'patterns', 'and', 'trends', 'by', 'means', 'such', 'as', 'statistical', 'pattern', 'learning', '.', 'According', 'to', 'Hotho', 'et', 'al', '.', '(', '2005', ')', 'we', 'can', 'distinguish', 'between', 'three', 'different', 'perspectives', 'of', 'text', 'mining', ':', 'information', 'extraction', ',', 'data', 'mining', ',', 'and', 'a', 'KDD', '(', 'Knowledge', 'Discovery', 'in', 'Databases', ')', 'process', '.', '[', '2', ']', 'Text', 'mining', 'usually', 'involves', 'the', 'process', 'of', 'structuring', 'the', 'input', 'text', '(', 'usually', 'parsing', ',', 'along', 'with', 'the', 'addition', 'of', 'some', 'derived', 'linguistic', 'features', 'and', 'the', 'removal', 'of', 'others', ',', 'and', 'subsequent', 'insertion', 'into', 'a', 'database', ')', ',', 'deriving', 'patterns', 'within', 'the', 'structured', 'data', ',', 'and', 'finally', 'evaluation', 'and', 'interpretation', 'of', 'the', 'output', '.', "'High", 'quality', "'", 'in', 'text', 'mining', 'usually', 'refers', 'to', 'some', 'combination', 'of', 'relevance', ',', 'novelty', ',', 'and', 'interest', '.', 'Typical', 'text', 'mining', 'tasks', 'include', 'text', 'categorization', ',', 'text', 'clustering', ',', 'concept/entity', 'extraction', ',', 'production', 'of', 'granular', 'taxonomies', ',', 'sentiment', 'analysis', ',', 'document', 'summarization', ',', 'and', 'entity', 'relation', 'modeling', '(', 'i.e.', ',', 'learning', 'relations', 'between', 'named', 'entities', ')', '.']

# %%
#tells how much times the characters are used
from nltk.probability import FreqDist
fd=FreqDist(word_token)
print(fd.most_common(10))
# Out:
# [(',', 24), ('text', 9), ('of', 9), ('.', 9), ('and', 9), ('the', 8), ('mining', 7), ('information', 5), ('to', 4), ('by', 4)]

# %%
#plots the above characters

import matplotlib.pyplot as plt
fd.plot(10,cumulative=False)
plt.show()

# %%
word_token
# Out:
# ['Text',
#  'mining',
#  ',',
#  'also',
#  'referred',
#  'to',
#  'as',
#  'text',
#  'data',
#  'mining',
#  ',',
#  'similar',
#  'to',
#  'text',
#  'analytics',
#  ',',
#  'is',
#  'the',
#  'process',
#  'of',
#  'deriving',
#  'high-quality',
#  'information',
#  'from',
#  'text',
#  '.',
#  'It',
#  'involves',
#  '``',
#  'the',
#  'discovery',
#  'by',
#  'computer',
#  'of',
#  'new',
#  ',',
#  'previously',
#  'unknown',
#  'information',
#  ',',
#  'by',
#  'automatically',
#  'extracting',
#  'information',
#  'from',
#  'different',
#  'written',
#  'resources',
#  '.',
#  '``',
#  '[',
#  '1',
#  ']',
#  'Written',
#  'resources',
#  'may',
#  'include',
#  'websites',
#  ',',
#  'books',
#  ',',
#  'emails',
#  ',',
#  'reviews',
#  ',',
#  'and',
#  'articles',
#  '.',
#  'High-quality',
#  'information',
#  'is',
#  'typically',
#  'obtained',
#  'by',
#  'devising',
#  'patterns',
#  'and',
#  'trends',
#  'by',
#  'means',
#  'such',
#  'as',
#  'statistical',
#  'pattern',
#  'learning',
#  '.',
#  'According',
#  'to',
#  'Hotho',
#  'et',
#  'al',
#  '.',
#  '(',
#  '2005',
#  ')',
#  'we',
#  'can',
#  'distinguish',
#  'between',
#  'three',
#  'different',
#  'perspectives',
#  'of',
#  'text',
#  'mining',
#  ':',
#  'information',
#  'extraction',
#  ',',
#  'data',
#  'mining',
#  ',',
#  'and',
#  'a',
#  'KDD',
#  '(',
#  'Knowledge',
#  'Discovery',
#  'in',
#  'Databases',
#  ')',
#  'process',
#  '.',
#  '[',
#  '2',
#  ']',
#  'Text',
#  'mining',
#  'usually',
#  'involves',
#  'the',
#  'process',
#  'of',
#  'structuring',
#  'the',
#  'input',
#  'text',
#  '(',
#  'usually',
#  'parsing',
#  ',',
#  'along',
#  'with',
#  'the',
#  'addition',
#  'of',
#  'some',
#  'derived',
#  'linguistic',
#  'features',
#  'and',
#  'the',
#  'removal',
#  'of',
#  'others',
#  ',',
#  'and',
#  'subsequent',
#  'insertion',
#  'into',
#  'a',
#  'database',
#  ')',
#  ',',
#  'deriving',
#  'patterns',
#  'within',
#  'the',
#  'structured',
#  'data',
#  ',',
#  'and',
#  'finally',
#  'evaluation',
#  'and',
#  'interpretation',
#  'of',
#  'the',
#  'output',
#  '.',
#  "'High",
#  'quality',
#  "'",
#  'in',
#  'text',
#  'mining',
#  'usually',
#  'refers',
#  'to',
#  'some',
#  'combination',
#  'of',
#  'relevance',
#  ',',
#  'novelty',
#  ',',
#  'and',
#  'interest',
#  '.',
#  'Typical',
#  'text',
#  'mining',
#  'tasks',
#  'include',
#  'text',
#  'categorization',
#  ',',
#  'text',
#  'clustering',
#  ',',
#  'concept/entity',
#  'extraction',
#  ',',
#  'production',
#  'of',
#  'granular',
#  'taxonomies',
#  ',',
#  'sentiment',
#  'analysis',
#  ',',
#  'document',
#  'summarization',
#  ',',
#  'and',
#  'entity',
#  'relation',
#  'modeling',
#  '(',
#  'i.e.',
#  ',',
#  'learning',
#  'relations',
#  'between',
#  'named',
#  'entities',
#  ')',
#  '.']

# %%
from nltk.corpus import stopwords
sw=set(stopwords.words('english'))
print(sw)
#nltk.download('stopwords')
# Out:
# {'wasn', 'ourselves', 'as', 'ain', "should've", 'shan', 'does', "it's", 'themselves', 'being', "you'd", 'weren', 'yourself', 't', 'hasn', 'only', 'this', 'me', 'an', 'ours', "aren't", 'haven', 'yours', 'before', 'those', 'are', 'them', 'most', 'into', 'so', 'any', 'through', 'himself', "won't", "you're", "you've", 'from', 'having', "shan't", 'off', 'again', 'up', 'who', 'other', 'yourselves', "couldn't", 'with', 'was', 'too', "wouldn't", 'then', 'you', 'to', 'isn', "mightn't", 'that', 'its', 'for', 'these', 'your', 'at', 'all', 'if', 'nor', 'do', 'more', 'some', "isn't", 'once', 'own', 'same', "didn't", 'couldn', 'each', 'will', 'don', 'him', "wasn't", 'which', 'herself', 'aren', 'll', 'against', 'down', 'on', 'doesn', 'by', 'mustn', 'can', 'here', 'below', 's', 'were', 'needn', 'have', 'her', "that'll", "hadn't", 'y', 'there', 'is', "doesn't", 'above', "hasn't", 'shouldn', 'myself', 'did', 'in', 'out', 'during', "haven't", 'theirs', 'not', 'itself', 'about', 'or', 'we', 'it', 'until', 'while', "don't", 'and', 'won', 'over', 'his', 'after', 'of', 'mightn', "shouldn't", 'but', 'between', "she's", 'hers', 'both', 'they', 'their', 'she', 'now', 'the', 'had', 'when', "weren't", "mustn't", 'few', 'i', 'where', 'm', 're', 'd', 'should', 'what', 'whom', 'very', 've', 'didn', 'how', 'hadn', 'my', 'such', 'has', 'ma', 'o', 'am', 'under', 'further', 'wouldn', 'no', 'be', 'our', 'a', 'because', 'than', "you'll", 'just', "needn't", 'doing', 'why', 'been', 'he'}

# %%
ft=[]
for words in word_token:
    if words not in sw:
        ft.append(words)
print("*************Tokenized words********")
print(word_token)
print("*****Filtered Tokens*******")
print(ft)
# Out:
# *************Tokenized words********
# ['Text', 'mining', ',', 'also', 'referred', 'to', 'as', 'text', 'data', 'mining', ',', 'similar', 'to', 'text', 'analytics', ',', 'is', 'the', 'process', 'of', 'deriving', 'high-quality', 'information', 'from', 'text', '.', 'It', 'involves', '``', 'the', 'discovery', 'by', 'computer', 'of', 'new', ',', 'previously', 'unknown', 'information', ',', 'by', 'automatically', 'extracting', 'information', 'from', 'different', 'written', 'resources', '.', '``', '[', '1', ']', 'Written', 'resources', 'may', 'include', 'websites', ',', 'books', ',', 'emails', ',', 'reviews', ',', 'and', 'articles', '.', 'High-quality', 'information', 'is', 'typically', 'obtained', 'by', 'devising', 'patterns', 'and', 'trends', 'by', 'means', 'such', 'as', 'statistical', 'pattern', 'learning', '.', 'According', 'to', 'Hotho', 'et', 'al', '.', '(', '2005', ')', 'we', 'can', 'distinguish', 'between', 'three', 'different', 'perspectives', 'of', 'text', 'mining', ':', 'information', 'extraction', ',', 'data', 'mining', ',', 'and', 'a', 'KDD', '(', 'Knowledge', 'Discovery', 'in', 'Databases', ')', 'process', '.', '[', '2', ']', 'Text', 'mining', 'usually', 'involves', 'the', 'process', 'of', 'structuring', 'the', 'input', 'text', '(', 'usually', 'parsing', ',', 'along', 'with', 'the', 'addition', 'of', 'some', 'derived', 'linguistic', 'features', 'and', 'the', 'removal', 'of', 'others', ',', 'and', 'subsequent', 'insertion', 'into', 'a', 'database', ')', ',', 'deriving', 'patterns', 'within', 'the', 'structured', 'data', ',', 'and', 'finally', 'evaluation', 'and', 'interpretation', 'of', 'the', 'output', '.', "'High", 'quality', "'", 'in', 'text', 'mining', 'usually', 'refers', 'to', 'some', 'combination', 'of', 'relevance', ',', 'novelty', ',', 'and', 'interest', '.', 'Typical', 'text', 'mining', 'tasks', 'include', 'text', 'categorization', ',', 'text', 'clustering', ',', 'concept/entity', 'extraction', ',', 'production', 'of', 'granular', 'taxonomies', ',', 'sentiment', 'analysis', ',', 'document', 'summarization', ',', 'and', 'entity', 'relation', 'modeling', '(', 'i.e.', ',', 'learning', 'relations', 'between', 'named', 'entities', ')', '.']
# *****Filtered Tokens*******
# ['Text', 'mining', ',', 'also', 'referred', 'text', 'data', 'mining', ',', 'similar', 'text', 'analytics', ',', 'process', 'deriving', 'high-quality', 'information', 'text', '.', 'It', 'involves', '``', 'discovery', 'computer', 'new', ',', 'previously', 'unknown', 'information', ',', 'automatically', 'extracting', 'information', 'different', 'written', 'resources', '.', '``', '[', '1', ']', 'Written', 'resources', 'may', 'include', 'websites', ',', 'books', ',', 'emails', ',', 'reviews', ',', 'articles', '.', 'High-quality', 'information', 'typically', 'obtained', 'devising', 'patterns', 'trends', 'means', 'statistical', 'pattern', 'learning', '.', 'According', 'Hotho', 'et', 'al', '.', '(', '2005', ')', 'distinguish', 'three', 'different', 'perspectives', 'text', 'mining', ':', 'information', 'extraction', ',', 'data', 'mining', ',', 'KDD', '(', 'Knowledge', 'Discovery', 'Databases', ')', 'process', '.', '[', '2', ']', 'Text', 'mining', 'usually', 'involves', 'process', 'structuring', 'input', 'text', '(', 'usually', 'parsing', ',', 'along', 'addition', 'derived', 'linguistic', 'features', 'removal', 'others', ',', 'subsequent', 'insertion', 'database', ')', ',', 'deriving', 'patterns', 'within', 'structured', 'data', ',', 'finally', 'evaluation', 'interpretation', 'output', '.', "'High", 'quality', "'", 'text', 'mining', 'usually', 'refers', 'combination', 'relevance', ',', 'novelty', ',', 'interest', '.', 'Typical', 'text', 'mining', 'tasks', 'include', 'text', 'categorization', ',', 'text', 'clustering', ',', 'concept/entity', 'extraction', ',', 'production', 'granular', 'taxonomies', ',', 'sentiment', 'analysis', ',', 'document', 'summarization', ',', 'entity', 'relation', 'modeling', '(', 'i.e.', ',', 'learning', 'relations', 'named', 'entities', ')', '.']

# %%
sw
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
import string
pt=[]
p=list(string.punctuation)
p
for i in ft:
    if i not in p:
        pt.append(i)
print("Filtered text without punctuation")
print(pt)
# Out:
# Filtered text without punctuation
# ['Text', 'mining', 'also', 'referred', 'text', 'data', 'mining', 'similar', 'text', 'analytics', 'process', 'deriving', 'high-quality', 'information', 'text', 'It', 'involves', '``', 'discovery', 'computer', 'new', 'previously', 'unknown', 'information', 'automatically', 'extracting', 'information', 'different', 'written', 'resources', '``', '1', 'Written', 'resources', 'may', 'include', 'websites', 'books', 'emails', 'reviews', 'articles', 'High-quality', 'information', 'typically', 'obtained', 'devising', 'patterns', 'trends', 'means', 'statistical', 'pattern', 'learning', 'According', 'Hotho', 'et', 'al', '2005', 'distinguish', 'three', 'different', 'perspectives', 'text', 'mining', 'information', 'extraction', 'data', 'mining', 'KDD', 'Knowledge', 'Discovery', 'Databases', 'process', '2', 'Text', 'mining', 'usually', 'involves', 'process', 'structuring', 'input', 'text', 'usually', 'parsing', 'along', 'addition', 'derived', 'linguistic', 'features', 'removal', 'others', 'subsequent', 'insertion', 'database', 'deriving', 'patterns', 'within', 'structured', 'data', 'finally', 'evaluation', 'interpretation', 'output', "'High", 'quality', 'text', 'mining', 'usually', 'refers', 'combination', 'relevance', 'novelty', 'interest', 'Typical', 'text', 'mining', 'tasks', 'include', 'text', 'categorization', 'text', 'clustering', 'concept/entity', 'extraction', 'production', 'granular', 'taxonomies', 'sentiment', 'analysis', 'document', 'summarization', 'entity', 'relation', 'modeling', 'i.e.', 'learning', 'relations', 'named', 'entities']

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize,word_tokenize
ps=PorterStemmer()
st=[]
for sw in pt:
    st.append(ps.stem(sw))
print("Removed Punctuated words",pt)
print("Stemmed Words")
print(st)
# Out:
# Removed Punctuated words ['Text', 'mining', 'also', 'referred', 'text', 'data', 'mining', 'similar', 'text', 'analytics', 'process', 'deriving', 'high-quality', 'information', 'text', 'It', 'involves', '``', 'discovery', 'computer', 'new', 'previously', 'unknown', 'information', 'automatically', 'extracting', 'information', 'different', 'written', 'resources', '``', '1', 'Written', 'resources', 'may', 'include', 'websites', 'books', 'emails', 'reviews', 'articles', 'High-quality', 'information', 'typically', 'obtained', 'devising', 'patterns', 'trends', 'means', 'statistical', 'pattern', 'learning', 'According', 'Hotho', 'et', 'al', '2005', 'distinguish', 'three', 'different', 'perspectives', 'text', 'mining', 'information', 'extraction', 'data', 'mining', 'KDD', 'Knowledge', 'Discovery', 'Databases', 'process', '2', 'Text', 'mining', 'usually', 'involves', 'process', 'structuring', 'input', 'text', 'usually', 'parsing', 'along', 'addition', 'derived', 'linguistic', 'features', 'removal', 'others', 'subsequent', 'insertion', 'database', 'deriving', 'patterns', 'within', 'structured', 'data', 'finally', 'evaluation', 'interpretation', 'output', "'High", 'quality', 'text', 'mining', 'usually', 'refers', 'combination', 'relevance', 'novelty', 'interest', 'Typical', 'text', 'mining', 'tasks', 'include', 'text', 'categorization', 'text', 'clustering', 'concept/entity', 'extraction', 'production', 'granular', 'taxonomies', 'sentiment', 'analysis', 'document', 'summarization', 'entity', 'relation', 'modeling', 'i.e.', 'learning', 'relations', 'named', 'entities']
# Stemmed Words
# ['text', 'mine', 'also', 'refer', 'text', 'data', 'mine', 'similar', 'text', 'analyt', 'process', 'deriv', 'high-qual', 'inform', 'text', 'it', 'involv', '``', 'discoveri', 'comput', 'new', 'previous', 'unknown', 'inform', 'automat', 'extract', 'inform', 'differ', 'written', 'resourc', '``', '1', 'written', 'resourc', 'may', 'includ', 'websit', 'book', 'email', 'review', 'articl', 'high-qual', 'inform', 'typic', 'obtain', 'devis', 'pattern', 'trend', 'mean', 'statist', 'pattern', 'learn', 'accord', 'hotho', 'et', 'al', '2005', 'distinguish', 'three', 'differ', 'perspect', 'text', 'mine', 'inform', 'extract', 'data', 'mine', 'kdd', 'knowledg', 'discoveri', 'databas', 'process', '2', 'text', 'mine', 'usual', 'involv', 'process', 'structur', 'input', 'text', 'usual', 'pars', 'along', 'addit', 'deriv', 'linguist', 'featur', 'remov', 'other', 'subsequ', 'insert', 'databas', 'deriv', 'pattern', 'within', 'structur', 'data', 'final', 'evalu', 'interpret', 'output', "'high", 'qualiti', 'text', 'mine', 'usual', 'refer', 'combin', 'relev', 'novelti', 'interest', 'typic', 'text', 'mine', 'task', 'includ', 'text', 'categor', 'text', 'cluster', 'concept/ent', 'extract', 'product', 'granular', 'taxonomi', 'sentiment', 'analysi', 'document', 'summar', 'entiti', 'relat', 'model', 'i.e.', 'learn', 'relat', 'name', 'entiti']

# %%
#nltk.download('wordnet')
from nltk.stem.wordnet import WordNetLemmatizer
lm=WordNetLemmatizer()
ps=PorterStemmer()
w='Connecting to India'
print('Stemmed Word',ps.stem(w))
print('Lemmatized Word',lm.lemmatize(w,"v"))
# Out:
# Stemmed Word connecting to india
# Lemmatized Word Connecting to India

# %%
from nltk import pos_tag
print("Tokenized words")
print(st)
ptg=pos_tag(st)
print("Pos Tags")
print(ptg)
# Out:
# Tokenized words
# ['text', 'mine', 'also', 'refer', 'text', 'data', 'mine', 'similar', 'text', 'analyt', 'process', 'deriv', 'high-qual', 'inform', 'text', 'it', 'involv', '``', 'discoveri', 'comput', 'new', 'previous', 'unknown', 'inform', 'automat', 'extract', 'inform', 'differ', 'written', 'resourc', '``', '1', 'written', 'resourc', 'may', 'includ', 'websit', 'book', 'email', 'review', 'articl', 'high-qual', 'inform', 'typic', 'obtain', 'devis', 'pattern', 'trend', 'mean', 'statist', 'pattern', 'learn', 'accord', 'hotho', 'et', 'al', '2005', 'distinguish', 'three', 'differ', 'perspect', 'text', 'mine', 'inform', 'extract', 'data', 'mine', 'kdd', 'knowledg', 'discoveri', 'databas', 'process', '2', 'text', 'mine', 'usual', 'involv', 'process', 'structur', 'input', 'text', 'usual', 'pars', 'along', 'addit', 'deriv', 'linguist', 'featur', 'remov', 'other', 'subsequ', 'insert', 'databas', 'deriv', 'pattern', 'within', 'structur', 'data', 'final', 'evalu', 'interpret', 'output', "'high", 'qualiti', 'text', 'mine', 'usual', 'refer', 'combin', 'relev', 'novelti', 'interest', 'typic', 'text', 'mine', 'task', 'includ', 'text', 'categor', 'text', 'cluster', 'concept/ent', 'extract', 'product', 'granular', 'taxonomi', 'sentiment', 'analysi', 'document', 'summar', 'entiti', 'relat', 'model', 'i.e.', 'learn', 'relat', 'name', 'entiti']
# Pos Tags
# [('text', 'NN'), ('mine', 'NN'), ('also', 'RB'), ('refer', 'VBP'), ('text', 'JJ'), ('data', 'NNS'), ('mine', 'NN'), ('similar', 'JJ'), ('text', 'NN'), ('analyt', 'NN'), ('process', 'NN'), ('deriv', 'VBD'), ('high-qual', 'JJ'), ('inform', 'NN'), ('text', 'NN'), ('it', 'PRP'), ('involv', 'VBZ'), ('``', '``'), ('discoveri', 'JJ'), ('comput', 'NN'), ('new', 'JJ'), ('previous', 'JJ'), ('unknown', 'JJ'), ('inform', 'NN'), ('automat', 'NN'), ('extract', 'NN'), ('inform', 'NN'), ('differ', 'NN'), ('written', 'VBN'), ('resourc', 'VBP'), ('``', '``'), ('1', 'CD'), ('written', 'VBN'), ('resourc', 'NN'), ('may', 'MD'), ('includ', 'VB'), ('websit', 'NN'), ('book', 'NN'), ('email', 'NN'), ('review', 'NN'), ('articl', 'IN'), ('high-qual', 'JJ'), ('inform', 'NN'), ('typic', 'NN'), ('obtain', 'VB'), ('devis', 'JJ'), ('pattern', 'JJ'), ('trend', 'NN'), ('mean', 'JJ'), ('statist', 'NN'), ('pattern', 'NN'), ('learn', 'VBP'), ('accord', 'NN'), ('hotho', 'NN'), ('et', 'FW'), ('al', 'NN'), ('2005', 'CD'), ('distinguish', 'JJ'), ('three', 'CD'), ('differ', 'NN'), ('perspect', 'NN'), ('text', 'NN'), ('mine', 'NN'), ('inform', 'NN'), ('extract', 'NN'), ('data', 'NNS'), ('mine', 'NN'), ('kdd', 'NN'), ('knowledg', 'NN'), ('discoveri', 'NN'), ('databas', 'NN'), ('process', 'NN'), ('2', 'CD'), ('text', 'NN'), ('mine', 'NN'), ('usual', 'JJ'), ('involv', 'NN'), ('process', 'NN'), ('structur', 'NN'), ('input', 'NN'), ('text', 'RB'), ('usual', 'JJ'), ('pars', 'NNS'), ('along', 'IN'), ('addit', 'NN'), ('deriv', 'NNS'), ('linguist', 'VBP'), ('featur', 'JJ'), ('remov', 'NN'), ('other', 'JJ'), ('subsequ', 'NN'), ('insert', 'JJ'), ('databas', 'NN'), ('deriv', 'NN'), ('pattern', 'NN'), ('within', 'IN'), ('structur', 'NN'), ('data', 'NNS'), ('final', 'JJ'), ('evalu', 'NN'), ('interpret', 'NN'), ('output', 'NN'), ("'high", 'POS'), ('qualiti', 'NN'), ('text', 'NN'), ('mine', 'NN'), ('usual', 'JJ'), ('refer', 'NN'), ('combin', 'NN'), ('relev', 'NN'), ('novelti', 'JJ'), ('interest', 'NN'), ('typic', 'NN'), ('text', 'NN'), ('mine', 'NN'), ('task', 'NN'), ('includ', 'NN'), ('text', 'NN'), ('categor', 'NN'), ('text', 'NN'), ('cluster', 'NN'), ('concept/ent', 'NN'), ('extract', 'JJ'), ('product', 'NN'), ('granular', 'JJ'), ('taxonomi', 'JJ'), ('sentiment', 'NN'), ('analysi', 'NN'), ('document', 'NN'), ('summar', 'NN'), ('entiti', 'VBP'), ('relat', 'JJ'), ('model', 'NN'), ('i.e.', 'NN'), ('learn', 'VBP'), ('relat', 'JJ'), ('name', 'NN'), ('entiti', 'NN')]
